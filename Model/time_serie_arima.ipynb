# %%
#0.Tải và kiểm tra thư viện cần thiết
#matplotlib
# %pip install matplotlib
import matplotlib
import matplotlib.pyplot as plt
#pandas
# %pip install pandas
import pandas as pd
#numpy
# %pip install numpy
import numpy as np
#Thông tin phiên bản
print(f"Pandas phien ban: {pd.__version__}")
print(f"Matplotlib phien ban: {matplotlib.__version__}")
print(f"Numpy phien ban: {np.__version__}")
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
# Pandas phien ban: 2.2.3
# Matplotlib phien ban: 3.10.3
# Numpy phien ban: 2.2.6
# [notice] A new release of pip is available: 23.2.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#1.Khai phá dữ liệu
df=pd.read_csv(r'world_population.csv')
df.info()
df.head()
df.plot()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Rank                         234 non-null    int64
#  1   CCA3                         234 non-null    object
#  2   Country/Territory            234 non-null    object
#  3   Capital                      234 non-null    object
#  4   Continent                    234 non-null    object
#  5   2022 Population              234 non-null    int64
#  6   2020 Population              234 non-null    int64
#  7   2015 Population              234 non-null    int64
#  8   2010 Population              234 non-null    int64
#  9   2000 Population              234 non-null    int64
#  10  1990 Population              234 non-null    int64
#  11  1980 Population              234 non-null    int64
#  12  1970 Population              234 non-null    int64
# ...
